# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Loop through all the cities in the list.
set_count = 1
record_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = "https://api.openweathermap.org/data/2.5/weather?&q=" + city.replace(" ","+") + "&units=Imperial&APPID="+weather_api_key

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_discription = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        
        
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_discription})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kodiak
# Processing Record 2 of Set 1 | maxixe
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | yumen
# Processing Record 5 of Set 1 | nelson bay
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | tirumullaivasal
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | esperance
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | agadir
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | dikson
# Processing Record 17 of Set 1 | inongo
# Processing Record 18 of Set 1 | jieshi
# Processing Record 19 of Set 1 | hailar
# Processing Record 20 of Set 1 | maria chiquita
# Processing Record 21 of Set 1 | henties bay
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | hasaki
# Processing Record 25 of Set 1 | ixtapa
# Processing Record 26 of Set 1 | rocha
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | coari
# Processing Record 29 of Set 1 | nome
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | sladkovo
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 36 of Set 1 | hengyang
# Processing Record 37 of Set 1 | luanda
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | kahului
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | scicli
# Processing Record 42 of Set 1 | jamestown
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 46 of Set 1 | shelburne
# Processing Record 47 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 1 | sterlitamak
# Processing Record 49 of Set 1 | sobolevo
# Processing Record 50 of Set 1 | hilo
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | geraldton
# Processing Record 3 of Set 2 | erzin
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | abu kamal
# Processing Record 6 of Set 2 | shingu
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | aklavik
# Processing Record 10 of Set 2 | muisne
# Processing Record 11 of Set 2 | agirish
# Processing Record 12 of Set 2 | almeirim
# Processing Record 13 of Set 2 | georgetown
# Processing Record 14 of Set 2 | jodhpur
# Processing Record 15 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 2 | pacific grove
# Processing Record 17 of Set 2 | joshimath
# Processing Record 18 of Set 2 | dalaba
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | brigantine
# Processing Record 21 of Set 2 | nanortalik
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | mahebourg
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | alta floresta
# Processing Record 26 of Set 2 | nemuro
# Processing Record 27 of Set 2 | atuona
# Processing Record 28 of Set 2 | starkville
# Processing Record 29 of Set 2 | alihe
# Processing Record 30 of Set 2 | alto araguaia
# Processing Record 31 of Set 2 | saint anthony
# Processing Record 32 of Set 2 | padang
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | vila
# Processing Record 35 of Set 2 | pevek
# Processing Record 36 of Set 2 | lompoc
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | provideniya
# Processing Record 39 of Set 2 | college
# Processing Record 40 of Set 2 | medea
# Processing Record 41 of Set 2 | lusambo
# Processing Record 42 of Set 2 | lata
# Processing Record 43 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 2 | chokurdakh
# Processing Record 45 of Set 2 | ust-nera
# Processing Record 46 of Set 2 | fairbanks
# Processing Record 47 of Set 2 | sao filipe
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | mount gambier
# Processing Record 50 of Set 2 | bonavista
# Processing Record 1 of Set 3 | ouargaye
# Processing Record 2 of Set 3 | lahij
# Processing Record 3 of Set 3 | port lincoln
# Processing Record 4 of Set 3 | aksu
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | coihaique
# Processing Record 7 of Set 3 | kunming
# Processing Record 8 of Set 3 | mar del plata
# Processing Record 9 of Set 3 | makinsk
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | mbini
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | flin flon
# Processing Record 14 of Set 3 | port hawkesbury
# Processing Record 15 of Set 3 | great bend
# Processing Record 16 of Set 3 | quesnel
# Processing Record 17 of Set 3 | tyret pervaya
# Processing Record 18 of Set 3 | saint-paul-les-dax
# Processing Record 19 of Set 3 | catamarca
# Processing Record 20 of Set 3 | hithadhoo
# Processing Record 21 of Set 3 | thiruvananthapuram
# Processing Record 22 of Set 3 | northam
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | salalah
# Processing Record 25 of Set 3 | isangel
# Processing Record 26 of Set 3 | port alfred
# Processing Record 27 of Set 3 | tuktoyaktuk
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | sayyan
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | manzil salim
# Processing Record 33 of Set 3 | vila franca do campo
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 3 | kapaa
# Processing Record 37 of Set 3 | uwayl
# City not found. Skipping...
# Processing Record 38 of Set 3 | surt
# Processing Record 39 of Set 3 | elat
# Processing Record 40 of Set 3 | manavalakurichi
# Processing Record 41 of Set 3 | keelung
# Processing Record 42 of Set 3 | stornoway
# Processing Record 43 of Set 3 | hofn
# Processing Record 44 of Set 3 | xuddur
# Processing Record 45 of Set 3 | kavieng
# Processing Record 46 of Set 3 | cayenne
# Processing Record 47 of Set 3 | puerto del rosario
# Processing Record 48 of Set 3 | sarangani
# Processing Record 49 of Set 3 | paragominas
# Processing Record 50 of Set 3 | romilly-sur-seine
# Processing Record 1 of Set 4 | melfort
# Processing Record 2 of Set 4 | chuy
# Processing Record 3 of Set 4 | termoli
# Processing Record 4 of Set 4 | nador
# Processing Record 5 of Set 4 | tarata
# Processing Record 6 of Set 4 | narsaq
# Processing Record 7 of Set 4 | jalu
# Processing Record 8 of Set 4 | kaeo
# Processing Record 9 of Set 4 | camacha
# Processing Record 10 of Set 4 | asyut
# Processing Record 11 of Set 4 | new norfolk
# Processing Record 12 of Set 4 | tame
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | olafsvik
# Processing Record 15 of Set 4 | kingsville
# Processing Record 16 of Set 4 | talnakh
# Processing Record 17 of Set 4 | kruisfontein
# Processing Record 18 of Set 4 | achisay
# City not found. Skipping...
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 4 | yar-sale
# Processing Record 22 of Set 4 | rawson
# Processing Record 23 of Set 4 | timbakion
# City not found. Skipping...
# Processing Record 24 of Set 4 | pushkino
# Processing Record 25 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 4 | batsfjord
# Processing Record 27 of Set 4 | mackenzie
# Processing Record 28 of Set 4 | kendari
# Processing Record 29 of Set 4 | mount isa
# Processing Record 30 of Set 4 | arraial do cabo
# Processing Record 31 of Set 4 | dawson creek
# Processing Record 32 of Set 4 | kpandae
# Processing Record 33 of Set 4 | mecca
# Processing Record 34 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 35 of Set 4 | shelabolikha
# Processing Record 36 of Set 4 | thunder bay
# Processing Record 37 of Set 4 | yinchuan
# Processing Record 38 of Set 4 | viedma
# Processing Record 39 of Set 4 | cuenca
# Processing Record 40 of Set 4 | liberty
# Processing Record 41 of Set 4 | vila velha
# Processing Record 42 of Set 4 | arlit
# Processing Record 43 of Set 4 | ribeira grande
# Processing Record 44 of Set 4 | tahara
# Processing Record 45 of Set 4 | korla
# Processing Record 46 of Set 4 | pleasanton
# Processing Record 47 of Set 4 | torbay
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | port hedland
# Processing Record 50 of Set 4 | uva
# Processing Record 1 of Set 5 | chiang klang
# Processing Record 2 of Set 5 | lavrentiya
# Processing Record 3 of Set 5 | maniitsoq
# Processing Record 4 of Set 5 | tomatlan
# Processing Record 5 of Set 5 | hami
# Processing Record 6 of Set 5 | manono
# Processing Record 7 of Set 5 | banbury
# Processing Record 8 of Set 5 | coquimbo
# Processing Record 9 of Set 5 | batagay
# Processing Record 10 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 5 | pisco
# Processing Record 12 of Set 5 | mednogorsk
# Processing Record 13 of Set 5 | kutum
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | santa luzia
# Processing Record 16 of Set 5 | constitucion
# Processing Record 17 of Set 5 | avera
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | volgodonsk
# Processing Record 20 of Set 5 | zhigansk
# Processing Record 21 of Set 5 | san patricio
# Processing Record 22 of Set 5 | porto novo
# Processing Record 23 of Set 5 | araouane
# Processing Record 24 of Set 5 | fort nelson
# Processing Record 25 of Set 5 | airai
# Processing Record 26 of Set 5 | kilindoni
# Processing Record 27 of Set 5 | laguna
# Processing Record 28 of Set 5 | merauke
# Processing Record 29 of Set 5 | santa isabel do rio negro
# Processing Record 30 of Set 5 | ostrovnoy
# Processing Record 31 of Set 5 | genhe
# Processing Record 32 of Set 5 | port elizabeth
# Processing Record 33 of Set 5 | banjar
# Processing Record 34 of Set 5 | la seyne-sur-mer
# Processing Record 35 of Set 5 | chara
# Processing Record 36 of Set 5 | san carlos
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | bowen
# Processing Record 39 of Set 5 | derzhavinsk
# Processing Record 40 of Set 5 | pawayan
# Processing Record 41 of Set 5 | fasa
# Processing Record 42 of Set 5 | coxcatlan
# Processing Record 43 of Set 5 | namibe
# Processing Record 44 of Set 5 | hluti
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 5 | jacqueville
# Processing Record 48 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 49 of Set 5 | thompson
# Processing Record 50 of Set 5 | kantang
# Processing Record 1 of Set 6 | kysyl-syr
# Processing Record 2 of Set 6 | aryanah
# Processing Record 3 of Set 6 | ola
# Processing Record 4 of Set 6 | yuma
# Processing Record 5 of Set 6 | peremyshlyany
# Processing Record 6 of Set 6 | pala
# Processing Record 7 of Set 6 | gola gokarannath
# Processing Record 8 of Set 6 | mildura
# Processing Record 9 of Set 6 | honningsvag
# Processing Record 10 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 6 | longyearbyen
# Processing Record 12 of Set 6 | beringovskiy
# Processing Record 13 of Set 6 | diego de almagro
# Processing Record 14 of Set 6 | tessalit
# Processing Record 15 of Set 6 | belmonte
# Processing Record 16 of Set 6 | yakhroma
# Processing Record 17 of Set 6 | ibra
# Processing Record 18 of Set 6 | aquin
# Processing Record 19 of Set 6 | santa maria
# Processing Record 20 of Set 6 | rincon
# Processing Record 21 of Set 6 | suoyarvi
# Processing Record 22 of Set 6 | gambo
# Processing Record 23 of Set 6 | yanji
# Processing Record 24 of Set 6 | sheridan
# Processing Record 25 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 6 | bubaque
# Processing Record 27 of Set 6 | bereda
# Processing Record 28 of Set 6 | santa cruz
# Processing Record 29 of Set 6 | vaitape
# Processing Record 30 of Set 6 | auki
# Processing Record 31 of Set 6 | buraydah
# Processing Record 32 of Set 6 | yulara
# Processing Record 33 of Set 6 | artyom
# Processing Record 34 of Set 6 | gebre guracha
# Processing Record 35 of Set 6 | caravelas
# Processing Record 36 of Set 6 | sibolga
# Processing Record 37 of Set 6 | tshikapa
# Processing Record 38 of Set 6 | bol
# Processing Record 39 of Set 6 | gornopravdinsk
# Processing Record 40 of Set 6 | pangnirtung
# Processing Record 41 of Set 6 | san quintin
# Processing Record 42 of Set 6 | bongandanga
# Processing Record 43 of Set 6 | saint-raymond
# Processing Record 44 of Set 6 | ilulissat
# Processing Record 45 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 6 | koslan
# Processing Record 47 of Set 6 | bastia
# Processing Record 48 of Set 6 | abay
# Processing Record 49 of Set 6 | norman wells
# Processing Record 50 of Set 6 | kunashak
# Processing Record 1 of Set 7 | luau
# Processing Record 2 of Set 7 | dubbo
# Processing Record 3 of Set 7 | grand gaube
# Processing Record 4 of Set 7 | nueva gerona
# Processing Record 5 of Set 7 | iralaya
# Processing Record 6 of Set 7 | vuktyl
# Processing Record 7 of Set 7 | chapais
# Processing Record 8 of Set 7 | bulalacao
# Processing Record 9 of Set 7 | zeerust
# Processing Record 10 of Set 7 | rabkavi
# Processing Record 11 of Set 7 | tancheng
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 7 | koubia
# Processing Record 15 of Set 7 | severo-kurilsk
# Processing Record 16 of Set 7 | puri
# Processing Record 17 of Set 7 | khonsa
# Processing Record 18 of Set 7 | goderich
# Processing Record 19 of Set 7 | neiafu
# Processing Record 20 of Set 7 | palana
# Processing Record 21 of Set 7 | san carlos de bariloche
# Processing Record 22 of Set 7 | vavuniya
# Processing Record 23 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 7 | port arthur
# Processing Record 25 of Set 7 | thongwa
# Processing Record 26 of Set 7 | tasiilaq
# Processing Record 27 of Set 7 | lima
# Processing Record 28 of Set 7 | ketchikan
# Processing Record 29 of Set 7 | petrolandia
# City not found. Skipping...
# Processing Record 30 of Set 7 | qasigiannguit
# Processing Record 31 of Set 7 | the valley
# Processing Record 32 of Set 7 | emerald
# Processing Record 33 of Set 7 | bandarbeyla
# Processing Record 34 of Set 7 | silale
# Processing Record 35 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 7 | saint-francois
# Processing Record 37 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 7 | rio gallegos
# Processing Record 39 of Set 7 | katherine
# Processing Record 40 of Set 7 | vanimo
# Processing Record 41 of Set 7 | katsuura
# Processing Record 42 of Set 7 | egvekinot
# Processing Record 43 of Set 7 | comodoro rivadavia
# Processing Record 44 of Set 7 | leningradskiy
# Processing Record 45 of Set 7 | lebu
# Processing Record 46 of Set 7 | itigi
# Processing Record 47 of Set 7 | igrim
# Processing Record 48 of Set 7 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 7 | nantucket
# Processing Record 50 of Set 7 | simao
# Processing Record 1 of Set 8 | sinjai
# Processing Record 2 of Set 8 | guerrero negro
# Processing Record 3 of Set 8 | karamea
# City not found. Skipping...
# Processing Record 4 of Set 8 | zemio
# Processing Record 5 of Set 8 | svetlaya
# Processing Record 6 of Set 8 | asau
# Processing Record 7 of Set 8 | el colomo
# Processing Record 8 of Set 8 | macapa
# Processing Record 9 of Set 8 | phangnga
# Processing Record 10 of Set 8 | coahuayana
# Processing Record 11 of Set 8 | bethel
# Processing Record 12 of Set 8 | fortuna
# Processing Record 13 of Set 8 | turukhansk
# Processing Record 14 of Set 8 | iskateley
# Processing Record 15 of Set 8 | kawalu
# Processing Record 16 of Set 8 | dickinson
# Processing Record 17 of Set 8 | saskylakh
# Processing Record 18 of Set 8 | yerofey pavlovich
# Processing Record 19 of Set 8 | varhaug
# Processing Record 20 of Set 8 | anadyr
# Processing Record 21 of Set 8 | toccoa
# Processing Record 22 of Set 8 | mangan
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | staraya poltavka
# Processing Record 25 of Set 8 | san jose
# Processing Record 26 of Set 8 | khandyga
# Processing Record 27 of Set 8 | byron bay
# Processing Record 28 of Set 8 | ponta do sol
# Processing Record 29 of Set 8 | trat
# Processing Record 30 of Set 8 | tsiroanomandidy
# Processing Record 31 of Set 8 | luganville
# Processing Record 32 of Set 8 | nikolskoye
# Processing Record 33 of Set 8 | meulaboh
# Processing Record 34 of Set 8 | billings
# Processing Record 35 of Set 8 | carnarvon
# Processing Record 36 of Set 8 | vestmanna
# Processing Record 37 of Set 8 | payo
# Processing Record 38 of Set 8 | piacabucu
# Processing Record 39 of Set 8 | kisesa
# Processing Record 40 of Set 8 | cairns
# Processing Record 41 of Set 8 | north myrtle beach
# Processing Record 42 of Set 8 | vanavara
# Processing Record 43 of Set 8 | puqi
# Processing Record 44 of Set 8 | ambilobe
# Processing Record 45 of Set 8 | tautira
# Processing Record 46 of Set 8 | kropotkin
# Processing Record 47 of Set 8 | ugoofaaru
# Processing Record 48 of Set 8 | kolding
# Processing Record 49 of Set 8 | tabou
# Processing Record 50 of Set 8 | urumqi
# Processing Record 1 of Set 9 | churapcha
# Processing Record 2 of Set 9 | qostanay
# Processing Record 3 of Set 9 | senanga
# Processing Record 4 of Set 9 | sola
# Processing Record 5 of Set 9 | tarskoye
# Processing Record 6 of Set 9 | qaqortoq
# Processing Record 7 of Set 9 | cruden bay
# City not found. Skipping...
# Processing Record 8 of Set 9 | karratha
# Processing Record 9 of Set 9 | shimoda
# Processing Record 10 of Set 9 | amahai
# Processing Record 11 of Set 9 | am timan
# Processing Record 12 of Set 9 | inirida
# Processing Record 13 of Set 9 | saint-pierre
# Processing Record 14 of Set 9 | gravdal
# Processing Record 15 of Set 9 | port pirie
# Processing Record 16 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 9 | kununurra
# Processing Record 18 of Set 9 | pale
# Processing Record 19 of Set 9 | la ronge
# Processing Record 20 of Set 9 | lazaro cardenas
# Processing Record 21 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | flinders
# Processing Record 23 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 9 | alofi
# Processing Record 25 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 9 | xinyang
# Processing Record 27 of Set 9 | miraflores
# Processing Record 28 of Set 9 | general pico
# Processing Record 29 of Set 9 | iqaluit
# Processing Record 30 of Set 9 | vardo
# Processing Record 31 of Set 9 | north bend
# Processing Record 32 of Set 9 | jaipur hat
# City not found. Skipping...
# Processing Record 33 of Set 9 | bideford
# Processing Record 34 of Set 9 | namatanai
# Processing Record 35 of Set 9 | san luis
# Processing Record 36 of Set 9 | diffa
# Processing Record 37 of Set 9 | inta
# Processing Record 38 of Set 9 | springfield
# Processing Record 39 of Set 9 | tevaitoa
# Processing Record 40 of Set 9 | massaguet
# Processing Record 41 of Set 9 | sampit
# Processing Record 42 of Set 9 | bambous virieux
# Processing Record 43 of Set 9 | saryg-sep
# Processing Record 44 of Set 9 | barcelos
# Processing Record 45 of Set 9 | naze
# Processing Record 46 of Set 9 | dumai
# Processing Record 47 of Set 9 | marovoay
# Processing Record 48 of Set 9 | haines junction
# Processing Record 49 of Set 9 | zhangye
# Processing Record 50 of Set 9 | salinopolis
# Processing Record 1 of Set 10 | mumbwa
# Processing Record 2 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 3 of Set 10 | berlevag
# Processing Record 4 of Set 10 | puerto cabezas
# Processing Record 5 of Set 10 | isiro
# Processing Record 6 of Set 10 | promakhoi
# City not found. Skipping...
# Processing Record 7 of Set 10 | nouadhibou
# Processing Record 8 of Set 10 | banes
# Processing Record 9 of Set 10 | gadung
# Processing Record 10 of Set 10 | agadez
# Processing Record 11 of Set 10 | vieux-habitants
# Processing Record 12 of Set 10 | fonte boa
# Processing Record 13 of Set 10 | copiapo
# Processing Record 14 of Set 10 | bacolod
# Processing Record 15 of Set 10 | sembakung
# Processing Record 16 of Set 10 | kaliua
# Processing Record 17 of Set 10 | rio grande
# Processing Record 18 of Set 10 | abu samrah
# Processing Record 19 of Set 10 | kimbe
# Processing Record 20 of Set 10 | quang ngai
# Processing Record 21 of Set 10 | lhokseumawe
# Processing Record 22 of Set 10 | tateyama
# Processing Record 23 of Set 10 | praia da vitoria
# Processing Record 24 of Set 10 | hamilton
# Processing Record 25 of Set 10 | moindou
# Processing Record 26 of Set 10 | komsomolskiy
# Processing Record 27 of Set 10 | onega
# Processing Record 28 of Set 10 | makakilo city
# Processing Record 29 of Set 10 | srednekolymsk
# Processing Record 30 of Set 10 | krasnogorskoye
# Processing Record 31 of Set 10 | sandwick
# Processing Record 32 of Set 10 | soma
# Processing Record 33 of Set 10 | straumen
# Processing Record 34 of Set 10 | paracuru
# Processing Record 35 of Set 10 | krasnyy kut
# Processing Record 36 of Set 10 | creel
# Processing Record 37 of Set 10 | nieuw amsterdam
# Processing Record 38 of Set 10 | champerico
# Processing Record 39 of Set 10 | marathon
# Processing Record 40 of Set 10 | tura
# Processing Record 41 of Set 10 | maningrida
# Processing Record 42 of Set 10 | bom jesus
# Processing Record 43 of Set 10 | surgut
# Processing Record 44 of Set 10 | touros
# Processing Record 45 of Set 10 | yamada
# Processing Record 46 of Set 10 | la tuque
# Processing Record 47 of Set 10 | tuatapere
# Processing Record 48 of Set 10 | christchurch
# Processing Record 49 of Set 10 | revyakino
# Processing Record 50 of Set 10 | thinadhoo
# Processing Record 1 of Set 11 | kalakamati
# Processing Record 2 of Set 11 | mao
# Processing Record 3 of Set 11 | dovers
# Processing Record 4 of Set 11 | ngerengere
# Processing Record 5 of Set 11 | cooma
# Processing Record 6 of Set 11 | the pas
# Processing Record 7 of Set 11 | arona
# Processing Record 8 of Set 11 | haverhill
# Processing Record 9 of Set 11 | mogadishu
# Processing Record 10 of Set 11 | robertsport
# Processing Record 11 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 11 | yerbogachen
# Processing Record 13 of Set 11 | bitung
# Processing Record 14 of Set 11 | leh
# Processing Record 15 of Set 11 | port maria
# Processing Record 16 of Set 11 | svetlogorsk
# Processing Record 17 of Set 11 | hobyo
# Processing Record 18 of Set 11 | ahipara
# Processing Record 19 of Set 11 | havre-saint-pierre
# Processing Record 20 of Set 11 | samarai
# Processing Record 21 of Set 11 | clyde river
# Processing Record 22 of Set 11 | horconcitos
# Processing Record 23 of Set 11 | acapulco
# Processing Record 24 of Set 11 | calama
# Processing Record 25 of Set 11 | portales
# Processing Record 26 of Set 11 | port hardy
# Processing Record 27 of Set 11 | sharan
# Processing Record 28 of Set 11 | westport
# Processing Record 29 of Set 11 | turka
# Processing Record 30 of Set 11 | maldonado
# Processing Record 31 of Set 11 | dunedin
# Processing Record 32 of Set 11 | yeppoon
# Processing Record 33 of Set 11 | ajdabiya
# Processing Record 34 of Set 11 | panzhihua
# Processing Record 35 of Set 11 | magadan
# Processing Record 36 of Set 11 | eyl
# Processing Record 37 of Set 11 | xichang
# Processing Record 38 of Set 11 | mus
# Processing Record 39 of Set 11 | louis trichardt
# Processing Record 40 of Set 11 | roma
# Processing Record 41 of Set 11 | qurayyat
# Processing Record 42 of Set 11 | ulundi
# Processing Record 43 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 44 of Set 11 | ramygala
# Processing Record 45 of Set 11 | dauphin
# Processing Record 46 of Set 11 | kumluca
# Processing Record 47 of Set 11 | teahupoo
# Processing Record 48 of Set 11 | ampanihy
# Processing Record 49 of Set 11 | havelock
# Processing Record 50 of Set 11 | hearst
# Processing Record 1 of Set 12 | baleshwar
# Processing Record 2 of Set 12 | bilma
# Processing Record 3 of Set 12 | roald
# Processing Record 4 of Set 12 | kirakira
# Processing Record 5 of Set 12 | aswan
# Processing Record 6 of Set 12 | bizhbulyak
# Processing Record 7 of Set 12 | nishihara
# Processing Record 8 of Set 12 | yakuplu
# Processing Record 9 of Set 12 | asfi
# Processing Record 10 of Set 12 | shakhovskaya
# Processing Record 11 of Set 12 | siegen
# Processing Record 12 of Set 12 | imeni poliny osipenko
# Processing Record 13 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 14 of Set 12 | alice springs
# Processing Record 15 of Set 12 | westerland
# Processing Record 16 of Set 12 | antalaha
# Processing Record 17 of Set 12 | hualmay
# Processing Record 18 of Set 12 | saint-augustin
# Processing Record 19 of Set 12 | lufilufi
# Processing Record 20 of Set 12 | waipawa
# Processing Record 21 of Set 12 | guiuan
# Processing Record 22 of Set 12 | los llanos de aridane
# Processing Record 23 of Set 12 | atocha
# Processing Record 24 of Set 12 | saint-joseph
# Processing Record 25 of Set 12 | dingle
# Processing Record 26 of Set 12 | denpasar
# Processing Record 27 of Set 12 | buin
# Processing Record 28 of Set 12 | faanui
# Processing Record 29 of Set 12 | russell
# Processing Record 30 of Set 12 | phalodi
# Processing Record 31 of Set 12 | omsukchan
# Processing Record 32 of Set 12 | virginia beach
# Processing Record 33 of Set 12 | nabire
# Processing Record 34 of Set 12 | alpoyeca
# Processing Record 35 of Set 12 | conde
# Processing Record 36 of Set 12 | dolores
# Processing Record 37 of Set 12 | wagga wagga
# Processing Record 38 of Set 12 | victor harbor
# Processing Record 39 of Set 12 | ewa beach
# Processing Record 40 of Set 12 | ponta delgada
# Processing Record 41 of Set 12 | deori khas
# Processing Record 42 of Set 12 | inhambane
# Processing Record 43 of Set 12 | ambon
# Processing Record 44 of Set 12 | ivanjica
# Processing Record 45 of Set 12 | portland
# Processing Record 46 of Set 12 | ahome
# Processing Record 47 of Set 12 | malanje
# Processing Record 48 of Set 12 | betsiamites
# Processing Record 49 of Set 12 | kapustin yar-1
# City not found. Skipping...
# Processing Record 50 of Set 12 | pelym
# Processing Record 1 of Set 13 | dandong
# Processing Record 2 of Set 13 | paamiut
# Processing Record 3 of Set 13 | peleduy
# Processing Record 4 of Set 13 | iskele
# City not found. Skipping...
# Processing Record 5 of Set 13 | birao
# Processing Record 6 of Set 13 | fort collins
# Processing Record 7 of Set 13 | maghama
# City not found. Skipping...
# Processing Record 8 of Set 13 | shahgarh
# Processing Record 9 of Set 13 | baykit
# Processing Record 10 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 13 | yaan
# Processing Record 12 of Set 13 | ochamchira
# Processing Record 13 of Set 13 | najran
# Processing Record 14 of Set 13 | jamame
# Processing Record 15 of Set 13 | krasnoselkup
# Processing Record 16 of Set 13 | batagay-alyta
# Processing Record 17 of Set 13 | wajima
# Processing Record 18 of Set 13 | saint george
# Processing Record 19 of Set 13 | araguacu
# Processing Record 20 of Set 13 | mackay
# Processing Record 21 of Set 13 | kiama
# Processing Record 22 of Set 13 | margate
# Processing Record 23 of Set 13 | minab
# Processing Record 24 of Set 13 | kushima
# Processing Record 25 of Set 13 | marsa matruh
# Processing Record 26 of Set 13 | las cruces
# Processing Record 27 of Set 13 | pinar del rio
# Processing Record 28 of Set 13 | manggar
# Processing Record 29 of Set 13 | gizo
# Processing Record 30 of Set 13 | carutapera
# Processing Record 31 of Set 13 | cockburn town
# Processing Record 32 of Set 13 | itaueira
# Processing Record 33 of Set 13 | obodivka
# Processing Record 34 of Set 13 | eravur
# Processing Record 35 of Set 13 | grindavik
# Processing Record 36 of Set 13 | willowmore
# Processing Record 37 of Set 13 | soyo
# Processing Record 38 of Set 13 | ossora
# Processing Record 39 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 13 | ajmer
# Processing Record 41 of Set 13 | puerto leguizamo
# Processing Record 42 of Set 13 | teacapan
# Processing Record 43 of Set 13 | paranapanema
# Processing Record 44 of Set 13 | benguela
# Processing Record 45 of Set 13 | bambanglipuro
# Processing Record 46 of Set 13 | worthington
# Processing Record 47 of Set 13 | salinas
# Processing Record 48 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 13 | pangai
# Processing Record 50 of Set 13 | te anau
# Processing Record 1 of Set 14 | nuuk
# Processing Record 2 of Set 14 | tarko-sale
# Processing Record 3 of Set 14 | totness
# Processing Record 4 of Set 14 | nhulunbuy
# Processing Record 5 of Set 14 | shaunavon
# Processing Record 6 of Set 14 | adrar
# Processing Record 7 of Set 14 | saint-paul
# Processing Record 8 of Set 14 | atlantic city
# Processing Record 9 of Set 14 | hilton head island
# Processing Record 10 of Set 14 | hirna
# Processing Record 11 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 12 of Set 14 | kismayo
# Processing Record 13 of Set 14 | obertyn
# Processing Record 14 of Set 14 | aitape
# Processing Record 15 of Set 14 | matara
# Processing Record 16 of Set 14 | vestmannaeyjar
# Processing Record 17 of Set 14 | burkhala
# City not found. Skipping...
# Processing Record 18 of Set 14 | jardim
# Processing Record 19 of Set 14 | pocoes
# Processing Record 20 of Set 14 | necochea
# Processing Record 21 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 22 of Set 14 | muros
# Processing Record 23 of Set 14 | calabozo
# Processing Record 24 of Set 14 | songkhla
# Processing Record 25 of Set 14 | ulladulla
# Processing Record 26 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 14 | youkounkoun
# Processing Record 28 of Set 14 | katobu
# Processing Record 29 of Set 14 | richards bay
# Processing Record 30 of Set 14 | oia
# Processing Record 31 of Set 14 | jacmel
# Processing Record 32 of Set 14 | novovasylivka
# Processing Record 33 of Set 14 | cap-aux-meules
# Processing Record 34 of Set 14 | kangaatsiaq
# Processing Record 35 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 14 | zhuhai
# Processing Record 37 of Set 14 | manati
# Processing Record 38 of Set 14 | aripuana
# Processing Record 39 of Set 14 | yuzhno-kurilsk
# Processing Record 40 of Set 14 | morgan city
# Processing Record 41 of Set 14 | dmytrivka
# Processing Record 42 of Set 14 | kemise
# Processing Record 43 of Set 14 | itarema
# Processing Record 44 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 45 of Set 14 | slonim
# Processing Record 46 of Set 14 | montijo
# Processing Record 47 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 14 | biak
# Processing Record 49 of Set 14 | half moon bay
# Processing Record 50 of Set 14 | port macquarie
# Processing Record 1 of Set 15 | kamaishi
# Processing Record 2 of Set 15 | ngaoundere
# Processing Record 3 of Set 15 | porvoo
# Processing Record 4 of Set 15 | nalut
# Processing Record 5 of Set 15 | priiskovyy
# Processing Record 6 of Set 15 | ankola
# Processing Record 7 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 8 of Set 15 | ucluelet
# Processing Record 9 of Set 15 | santander
# Processing Record 10 of Set 15 | deputatskiy
# Processing Record 11 of Set 15 | menemen
# Processing Record 12 of Set 15 | serebryanyy bor
# Processing Record 13 of Set 15 | slavyanka
# Processing Record 14 of Set 15 | kholodnyy
# Processing Record 15 of Set 15 | mazatan
# Processing Record 16 of Set 15 | aasiaat
# Processing Record 17 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 18 of Set 15 | kahta
# Processing Record 19 of Set 15 | pitimbu
# Processing Record 20 of Set 15 | dwarka
# Processing Record 21 of Set 15 | broken hill
# Processing Record 22 of Set 15 | gadu
# Processing Record 23 of Set 15 | konevo
# Processing Record 24 of Set 15 | male
# Processing Record 25 of Set 15 | tairua
# Processing Record 26 of Set 15 | husavik
# Processing Record 27 of Set 15 | atasu
# Processing Record 28 of Set 15 | la palma
# Processing Record 29 of Set 15 | pulandian
# Processing Record 30 of Set 15 | harper
# Processing Record 31 of Set 15 | panaba
# Processing Record 32 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 15 | oranjemund
# Processing Record 34 of Set 15 | gijon
# Processing Record 35 of Set 15 | stolin
# Processing Record 36 of Set 15 | tulun
# Processing Record 37 of Set 15 | nadym
# Processing Record 38 of Set 15 | warrnambool
# Processing Record 39 of Set 15 | palmer
# Processing Record 40 of Set 15 | pekalongan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Kodiak      US  57.79 -152.41     60.80        72          20
# 1           Maxixe      MZ -23.86   35.35     59.95        81           0
# 2     Puerto Ayora      EC  -0.74  -90.35     64.99        97          77
# 3            Yumen      CN  40.28   97.20     80.85        22           0
# 4       Nelson Bay      AU -32.72  152.15     62.60        36           0
# 5          Rikitea      PF -23.12 -134.97     67.21        75         100
# 6            Bluff      NZ -46.60  168.33     57.00        74          89
# 7        Busselton      AU -33.65  115.33     63.00        54          17
# 8  Tirumullaivasal      IN  11.23   79.83     86.16        69          87
# 9            Tiksi      RU  71.69  128.87     41.72        90         100
#
#    Wind Speed Current Description
# 0        6.73          few clouds
# 1        0.67           clear sky
# 2        8.72       broken clouds
# 3        8.50           clear sky
# 4       26.40           clear sky
# 5       19.30     overcast clouds
# 6       10.00     overcast clouds
# 7       11.88          few clouds
# 8       11.39       moderate rain
# 9        2.86          light rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
